# %% [markdown]
# ### Heroes Of Pymoli Data Analysis
# * Of the 1163 active players, the vast majority are male (84%). There also exists, a smaller, but notable proportion of female players (14%).
#
# * Our peak age demographic falls between 20-24 (44.8%) with secondary groups falling between 15-19 (18.60%) and 25-29 (13.4%).
# -----

# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Raw data file
file_to_load = "Resources/purchase_data.csv"

# Read purchasing file and store into pandas data frame
purchase_data = pd.read_csv(file_to_load)

# %% [markdown]
# ## Player Count

# %% [markdown]
# * Display the total number of players

# %%
#Just a quick question, was it supposed to show everything right away? I'm gonna leave lots of comments cuz I don't wanna look like I cheated
purchase_data.dtypes #I wanna know what data types we have first. 
#purchase_data.head() #I wanna visualize the data, this is also to confirm the read worked
#purchase_data.count()#display the number of players via the length functionm or rather I tried to, the count function worked. It returned 780 players
# Out:
# Purchase ID      int64
# SN              object
# Age              int64
# Gender          object
# Item ID          int64
# Item Name       object
# Price          float64
# dtype: object

# %%
#purchase_data['SN'] = pd.to_numeric(purchase_data['SN']) attempted to change SN to numeric in hopes I could use len to analyze it, it didn't work
purchase_data.describe #attempted to use the describe fuction. It was successful, but it's ugly. Needs cleaning for sure
#After reading the data I'm aware that there are actually 779 players, the header should be excluded. My answer to the first question is 779. And that's my final answer!
# Out:
# <bound method NDFrame.describe of      Purchase ID               SN  Age                 Gender  Item ID  \
# 0              0          Lisim78   20                   Male      108
# 1              1      Lisovynya38   40                   Male      143
# 2              2       Ithergue48   24                   Male       92
# 3              3    Chamassasya86   24                   Male      100
# 4              4        Iskosia90   23                   Male      131
# 5              5          Yalae81   22                   Male       81
# 6              6        Itheria73   36                   Male      169
# 7              7      Iskjaskst81   20                   Male      162
# 8              8        Undjask33   22                   Male       21
# 9              9      Chanosian48   35  Other / Non-Disclosed      136
# 10            10        Inguron55   23                   Male       95
# 11            11     Haisrisuir60   23                   Male      162
# ...

# %% [markdown]
# ## Purchasing Analysis (Total)

# %% [markdown]
# * Run basic calculations to obtain number of unique items, average price, etc.
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#purchase_data['Item ID'].value_counts() #returned that there are 183 distinct items
#purchase_data['Price'].mean() #recieved an odd key error, may need to drop or convert some of the values
#print(purchase_data['Price']) #I forgot to capitalize the P, oops!
#The average price of the purchases is 3.050987179487176
#purchase_data['Price'].value_counts() #The most commonly purchased item is 4.40, and the next two most common purchases underneath it are sinilarly priced, worth noting later

plt.figure(figsize=(20,5))
x_axis = purchase_data['Age']
y_axis = purchase_data['Price']
plt.scatter(x_axis, y_axis, marker="x", facecolors="black", edgecolors="blue",
            s=y_axis, alpha=0.75)
plt.title("Age of Players vs Purchases")
plt.xlabel("Age of Player")
plt.ylabel("Purchase Price")
#I am gonna admit my only off day is Monday so by the time I started this we were on matplotlib. Using a scatter chart organized by Age I can see that most purchases are made by people in the age range of the late teens to mid 20s, and most of the purchases are between 3-4 dollars give or take 50 cents
#I know it asked for a data frame, but a picture is worth a thousand words.
# Out:
# Text(0,0.5,'Purchase Price')

# %% [markdown]
# ## Gender Demographics

# %% [markdown]
# * Percentage and Count of Male Players
#
#
# * Percentage and Count of Female Players
#
#
# * Percentage and Count of Other / Non-Disclosed

# %%
purchase_data['Gender'].value_counts()
#There are 652 males, 113 females, and 15 Nonbinary??? k I don't like to judge
# Out:
# Male                     652
# Female                   113
# Other / Non-Disclosed     15
# Name: Gender, dtype: int64

# %% [markdown]
# ## Purchasing Analysis (Gender)

# %% [markdown]
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. by gender
#
#
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#purchase_data['Item Name'].value_counts() 
#purchase_data['Item ID'].value_counts() 
#purchase_data['Purchase ID'].value_counts()
#purchase_data['Item Name'].max() 'Yearning Mageblade' was the max for this column
#purchase_data['Item Name'].min() 'Abyssal Shard' was the min for this column
GD = purchase_data.set_index("Gender")
MGD = GD.loc["Male", "Price"]
#MGD.mean() #The average spent by males is 3.0178527607361953
FGD = GD.loc["Female", "Price"]
#FGD.mean() #the average spent by females is 3.203008849557519, females spend more than males
AGD =GD.loc["Other / Non-Disclosed", "Price"] #I didn't have to put a space after the = to get the line to work. neato
#AGD.mean() #the average spent by Attack Helicopters(this is a joke) is 3.3460000000000005, which is even higher than females. Thought low in number, they seem willing to purchase more. Important
del GD['Purchase ID']
GDS = GD.sort_values("Price", ascending=False)
GDS
# Out:
#                     SN  Age  Item ID                          Item Name  Price
# Gender
# Male          Dyally87   22       63                     Stormfury Mace   4.99
# Male          Hiasri33   23       63                     Stormfury Mace   4.99
# Male           Ririp86   25      139            Mercy, Katana of Dismay   4.94
# Male        Lirtilsa71   24      139            Mercy, Katana of Dismay   4.94
# Male     Chanirrasta87   14      139            Mercy, Katana of Dismay   4.94
# Male      Lassilsala30   21      139            Mercy, Katana of Dismay   4.94
# Male    Yarithsurgue62   26      139            Mercy, Katana of Dismay   4.94
# Male        Mindossa76   41      173                Stormfury Longsword   4.93
# Male        Chadjask77    8      147  Hellreaver, Heirloom of Inception   4.93
# Male       Idastidru52   24      147  Hellreaver, Heirloom of Inception   4.93
# Male       Smaistysu35   30      173                Stormfury Longsword   4.93
# ...

# %% [markdown]
# ## Age Demographics

# %% [markdown]
# * Establish bins for ages
#
#
# * Categorize the existing players using the age bins. Hint: use pd.cut()
#
#
# * Calculate the numbers and percentages by age group
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: round the percentage column to two decimal points
#
#
# * Display Age Demographics Table

# %%
# Establish bins for ages
age_bins = [0, 9.90, 14.90, 19.90, 24.90, 29.90, 34.90, 39.90, 99999]
group_names = ["<10", "10-14", "15-19", "20-24", "25-29", "30-34", "35-39", "40+"]
purchase_data["Age Group"] = pd.cut(purchase_data["Age"], age_bins, labels=group_names)
SPD = purchase_data.sort_values("Age Group", ascending=False)
SPDI =SPD.set_index("SN")
SPDI
# Out:
#                Purchase ID  Age  Gender  Item ID  \
# SN
# Hiasurria41            341   41    Male       71
# Eyrian71                23   40    Male      151
# Assim27                761   45    Male       17
# Chanosiaya39           728   44    Male       93
# Eyrian71               156   40    Male      117
# Salilis27              480   40    Male       59
# Frichaya88             557   42    Male        8
# Mindossa76             477   41    Male      173
# Jiskjask85             220   40    Male       46
# Isursuir31             248   44    Male      137
# Inasuir29              667   40  Female       66
# Aeral68                674   43    Male       77
# Lisovynya38              1   40    Male      143
# Qilanrion65            208   37    Male      105
# Lamil79                182   38    Male      154
# Phistym51              202   37    Male       82
# Eusur90                738   36    Male      121
# Maradaran90            196   35  Female        9
# ...

# %% [markdown]
# ## Purchasing Analysis (Age)

# %% [markdown]
# * Bin the purchase_data data frame by age
#
#
# * Run basic calculations to obtain purchase count, avg. purchase price, avg. purchase total per person etc. in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display the summary data frame

# %%
#SPDI.sum() #All I can glean from this is the total purchases equal 2379.77 HereComesTheMoney.mp3!
#SPDI["Item Name"].value_counts() #Final Critic was purchased most often

# %% [markdown]
# ## Top Spenders

# %% [markdown]
# * Run basic calculations to obtain the results in the table below
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the total purchase value column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
#wanna use ILoc to search this but having issues. :/
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1789                 if not ax.contains(key):
# -> 1790                     error()
#    1791             except TypeError as e:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in error()
#    1784                                .format(key=key,
# -> 1785                                        axis=self.obj._get_axis_name(axis)))
#    1786
#
# KeyError: 'the label [SN] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-9b0d904adc2e> in <module>()
# ----> 1 SPDL = SPDI.loc["SN", "Item Name"]
#       2 SPDL
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
# ...

# %% [markdown]
# ## Most Popular Items

# %% [markdown]
# * Retrieve the Item ID, Item Name, and Item Price columns
#
#
# * Group by Item ID and Item Name. Perform calculations to obtain purchase count, item price, and total purchase value
#
#
# * Create a summary data frame to hold the results
#
#
# * Sort the purchase count column in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the summary data frame

# %%
#SPD['Item Name'].value_counts() #Three most popular items are Final Critic, Oathbreaker, Last Hope of the Breaking Storm, and  Nirvana
#PDL = SPD.iloc["Final Critic", "Price"]
#ILoc isn't working for me :/ sad days
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _has_valid_tuple(self, key)
#     221             try:
# --> 222                 self._validate_key(k, i)
#     223             except ValueError:
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1970             raise ValueError("Can only index by location with "
# -> 1971                              "a [{types}]".format(types=self._valid_types))
#    1972
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-da7e2ea2037e> in <module>()
# ...

# %% [markdown]
# ## Most Profitable Items

# %% [markdown]
# * Sort the above table by total purchase value in descending order
#
#
# * Optional: give the displayed data cleaner formatting
#
#
# * Display a preview of the data frame

# %%
#SPDI["Item Name"].value_counts() #Final Critic was purchased most often, Follows by Oathbreaker, Last Hope of the Breaking Storm
SPDP = SPD.set_index("Price")
SPDP2 = SPDP.sort_values("Price", ascending=False)
SPDP2 
#Nirvana costs 4.90, and is purchased 9 times, it also appeals to Males and Females and various age groups. It is very profitable
# Out:
#        Purchase ID              SN  Age  Gender  Item ID  \
# Price
# 4.99           189        Hiasri33   23    Male       63
# 4.99           554        Dyally87   22    Male       63
# 4.94           246      Lirtilsa71   24    Male      139
# 4.94           110         Ririp86   25    Male      139
# 4.94           493   Chanirrasta87   14    Male      139
# 4.94           116    Lassilsala30   21    Male      139
# 4.94           231  Yarithsurgue62   26    Male      139
# 4.93           477      Mindossa76   41    Male      173
# 4.93           312     Strithenu87   20    Male      147
# 4.93           275     Smaistysu35   30    Male      173
# 4.93           686      Chadjask77    8    Male      147
# 4.93           290     Idastidru52   24    Male      147
# 4.91           388          Aeda94   17    Male      128
# 4.91           593      Lassimla92   25    Male      128
# 4.91           517  Aerithnuphos61   39    Male      128
# ...
